# %% [markdown]
# # Nested sampling results

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
try:
    sys.path.remove("../src") # Remove src if already exists 
except:
    pass
sys.path.append("../src") # Means that I dont have to make src/ a proper python package

# %%
path = '../data/nested_sampling/'
suffix = '_result.json'
from plotting import plot_nested_sampling_results

# %% [markdown]
# ## test123

# %%
plot_nested_sampling_results(path+'test123'+suffix)
# Out:
# Loading results from ../data/nested_sampling/test123_result.json
# Model evidence is 202412.03184255768
# The number of samples is 3834

# %% [markdown]
# # fast5

# %%
plot_nested_sampling_results(path+'fast5'+suffix)
# Out:
# Loading results from ../data/nested_sampling/fast5_result.json
# Model evidence is 247055.00185320913
# The number of samples is 6326

# %% [markdown]
# # fast6

# %%
ranges=[None,None,None,None,None,None,(0.5*5e-15,1.5*5e-15)]
plot_nested_sampling_results(path+'fast6'+suffix)
# Out:
# Loading results from ../data/nested_sampling/fast6_result.json
# Model evidence is 257105.4656307168
# The number of samples is 8469
# The median values are omega_gw    7.981629e-07
# phi0_gw     6.230088e-01
# psi_gw      2.585662e+00
# iota_gw     1.407775e+00
# delta_gw    7.685048e-01
# alpha_gw    1.339486e+00
# h           1.192180e-15
# dtype: float64
