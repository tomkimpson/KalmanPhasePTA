# %% [markdown]
# # Nested sampling results

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
try:
    sys.path.remove("../src") # Remove src if already exists 
except:
    pass
sys.path.append("../src") # Means that I dont have to make src/ a proper python package

# %%
path = '../data/nested_sampling/training_wheels_1/'
suffix = '_result.json'
from plotting import plot_nested_sampling_results

# %% [markdown]
# ## $h = 10^{-12}$

# %%
import numpy as np 
#ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(0.5*1e-12,1.5*1e-15)]
ranges=None
plot_nested_sampling_results(path+'TW_batch_1e-12'+suffix,ranges=ranges)
# Out:
# Loading results from ../data/nested_sampling/training_wheels_1/TW_batch_1e-12_result.json
# Model evidence is -257154.5643314586
# The number of samples is 10062
# The median values are omega_gw    4.997171e-07
# phi0_gw     4.044311e-01
# psi_gw      2.066543e+00
# iota_gw     4.498585e-03
# delta_gw    5.683565e-01
# alpha_gw    1.349604e-01
# h           8.999691e-15
# dtype: float64

# %% [markdown]
# ## $h = 10^{-13}$

# %%
plot_nested_sampling_results(path+'TW_batch_1e-13'+suffix)
# Out:
# Loading results from ../data/nested_sampling/training_wheels_1/TW_batch_1e-13_result.json
# Model evidence is 199209.95680715618
# The number of samples is 10773
# The median values are omega_gw    4.995849e-07
# phi0_gw     4.699443e-01
# psi_gw      2.238061e+00
# iota_gw     2.165894e-02
# delta_gw    3.985595e-01
# alpha_gw    1.937518e-01
# h           8.994963e-15
# dtype: float64

# %% [markdown]
# ## $h=10^{-14}$

# %%
plot_nested_sampling_results(path+'TW_batch_1e-14'+suffix)
# Out:
# Loading results from ../data/nested_sampling/training_wheels_1/TW_batch_1e-14_result.json
# Model evidence is 202397.21124116593
# The number of samples is 11538
# The median values are omega_gw    4.987140e-07
# phi0_gw     7.016585e-01
# psi_gw      1.189776e+00
# iota_gw     6.099884e-01
# delta_gw    1.071738e+00
# alpha_gw    2.805316e+00
# h           6.372351e-15
# dtype: float64

# %% [markdown]
# ## $h =10^{-15}$

# %%
plot_nested_sampling_results(path+'TW_batch_1e-15'+suffix)
# Out:
# Loading results from ../data/nested_sampling/training_wheels_1/TW_batch_1e-15_result.json
# Model evidence is 202421.3160356638
# The number of samples is 6518
# The median values are omega_gw    6.231620e-07
# phi0_gw     8.462463e-01
# psi_gw      1.571358e+00
# iota_gw     9.424954e-01
# delta_gw    6.942160e-01
# alpha_gw    1.826192e+00
# h           2.994087e-15
# dtype: float64
