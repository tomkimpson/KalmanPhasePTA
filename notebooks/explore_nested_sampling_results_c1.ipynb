# %% [markdown]
# # Nested sampling results

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
try:
    sys.path.remove("../src") # Remove src if already exists 
except:
    pass
sys.path.append("../src") # Means that I dont have to make src/ a proper python package

# %%
path = '../data/nested_sampling/canonical_1/'
suffix = '_result.json'
from plotting import plot_multiple_nested_sampling_results

# %%
import numpy as np 
ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(0.5*5e-15,1.5*5e-15)]
injection_parameters = injection_parameters = [5e-7,0.20,2.50,1.0,1.0,1.0,5e-15]

plot_multiple_nested_sampling_results(path,ranges=ranges,injection_parameters=injection_parameters)
# Out:
# ../data/nested_sampling/canonical_1/seed_1245_canonical_1.npy
# ../data/nested_sampling/canonical_1/seed_1246_canonical_1.npy
# ../data/nested_sampling/canonical_1/seed_1247_canonical_1.npy
# ../data/nested_sampling/canonical_1/seed_1248_canonical_1.npy
# ../data/nested_sampling/canonical_1/seed_1249_canonical_1.npy
# ../data/nested_sampling/canonical_1/seed_1250_canonical_1.npy
# ../data/nested_sampling/canonical_1/seed_1251_canonical_1.npy
# ../data/nested_sampling/canonical_1/seed_1252_canonical_1.npy
# ../data/nested_sampling/canonical_1/seed_1253_canonical_1.npy
# ../data/nested_sampling/canonical_1/seed_1254_canonical_1.npy
