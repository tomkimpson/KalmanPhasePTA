# %% [markdown]
# # Nested sampling results

# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
try:
    sys.path.remove("../src") # Remove src if already exists 
except:
    pass
sys.path.append("../src") # Means that I dont have to make src/ a proper python package

# %%
path = '../data/nested_sampling/training_wheels_2/'
suffix = '_result.json'
from plotting import plot_nested_sampling_results

# %% [markdown]
# ## $h = 10^{-12}$

# %%
# import numpy as np 
# #ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(0.5*1e-12,1.5*1e-15)]
# ranges=None
# plot_nested_sampling_results(path+'TW_batch_1e-12'+suffix,ranges=ranges)

# %% [markdown]
# ## $h = 10^{-13}$

# %%
import numpy as np 
ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(0.5*1e-13,1.5*1e-13)]
plot_nested_sampling_results(path+'TW2_1e-13'+suffix,ranges=ranges,savefig='phase_example')
# Out:
# Loading results from ../data/nested_sampling/training_wheels_2/TW2_1e-13_result.json
# Model evidence is 202290.38429345304
# The number of samples is 9808
# The median values are omega_gw    4.998115e-07
# phi0_gw     2.585766e-01
# psi_gw      2.557972e+00
# iota_gw     2.152006e-01
# delta_gw    1.001166e+00
# alpha_gw    1.013128e+00
# h           5.918885e-14
# dtype: float64

# %% [markdown]
# ## $h=10^{-14}$

# %%
ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(0.5*1e-14,1.5*1e-14)]
plot_nested_sampling_results(path+'TW2_1e-14'+suffix,ranges=ranges)
# Out:
# Loading results from ../data/nested_sampling/training_wheels_2/TW2_1e-14_result.json
# Model evidence is 202394.7808494786
# The number of samples is 9812
# The median values are omega_gw    4.984018e-07
# phi0_gw     7.756135e-01
# psi_gw      2.734865e+00
# iota_gw     8.488841e-01
# delta_gw    1.023728e+00
# alpha_gw    1.262184e+00
# h           7.418244e-15
# dtype: float64

# %% [markdown]
# ## $h =10^{-15}$

# %%
ranges=[(4.95e-7,5.05e-7),(-0.2,1.0),(2.0,3.0),(-0.2,np.pi/2),(0.5,1.5),(0.5,1.5),(0.5*1e-15,1.5*1e-15)]
plot_nested_sampling_results(path+'TW2_1e-15'+suffix)
# Out:
# Loading results from ../data/nested_sampling/training_wheels_2/TW2_1e-15_result.json
# Model evidence is 202421.72717330884
# The number of samples is 5400
# The median values are omega_gw    5.521441e-07
# phi0_gw     7.321299e-01
# psi_gw      1.661293e+00
# iota_gw     1.027218e+00
# delta_gw    8.219547e-01
# alpha_gw    1.481522e+00
# h           3.099453e-15
# dtype: float64
